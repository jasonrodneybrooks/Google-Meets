# %%
import pandas as pd
import numpy as np
import pandas_profiling

# %%
df = pd.read_csv("/Users/jasonbrooks/Downloads/drive_logs_1584488002680.csv")

df.head()
# Out:
#                                            Item name  \
# 0            P&P Reading XI (Virtual School Edition)
# 1            P&P Reading XI (Virtual School Edition)
# 2                        Anna Cox Hebrew Bible Notes
# 3  Activismo Artístico  (Mar 14, 2020 at 4_18 PM...
# 4            P&P Reading XI (Virtual School Edition)
#
#                                    Event Description                     User  \
# 0             zinan.aguirre@es-la.com viewed an item  zinan.aguirre@es-la.com
# 1  pearson@es-la.com added an item to P&P Reading...        pearson@es-la.com
# 2                  anna.cox@es-la.com edited an item       anna.cox@es-la.com
# 3                   garcia@es-la.com trashed an item         garcia@es-la.com
# 4  zinan.aguirre@es-la.com changed sharing permis...  zinan.aguirre@es-la.com
#
#                            Date                       Event Name  \
# 0  Mar 17, 2020, 4:33:17 PM PDT                             View
# ...

# %%
pfr = pandas_profiling.ProfileReport(df)
pfr.to_notebook_iframe()
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.4.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df['User'].value_counts()
# Out:
# valenzuela@es-la.com        8895
# spencer@es-la.com           7183
# brooks@es-la.com            3438
# david.loke@es-la.com        3228
# grant@es-la.com             1996
#                             ...
# leus@vakili.com                1
# brendanmalloyx@gmail.com       1
# lisawhiteman@gmail.com         1
# rebecca@voxfemina.org          1
# beate@haslinger.com            1
# Name: User, Length: 340, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Mar 11, 2020, 9:55:06 AM PDT     715
# Mar 11, 2020, 10:24:52 AM PDT    492
# Mar 11, 2020, 10:24:53 AM PDT    468
# Mar 11, 2020, 10:24:55 AM PDT    438
# Mar 11, 2020, 9:55:07 AM PDT     414
#                                 ...
# Mar 11, 2020, 12:22:27 PM PDT      1
# Mar 14, 2020, 11:54:32 PM PDT      1
# Mar 10, 2020, 10:01:26 AM PDT      1
# Mar 11, 2020, 1:56:44 PM PDT       1
# Mar 16, 2020, 2:17:46 PM PDT       1
# Name: Date, Length: 58608, dtype: int64

# %%
df['Event_Description'].value_counts()
# Out:
# spencer@es-la.com changed sharing permissions for spencer@es-la.com from None to Can edit                                       3041
# Jason Brooks changed sharing permissions for brooks@es-la.com from None to Can edit                                             2290
# grant@es-la.com changed sharing permissions for grant@es-la.com from None to Can edit                                           1790
# spencer@es-la.com changed link sharing visibility from Private to Anyone within the domain for es-la.com                        1734
# spencer@es-la.com changed link sharing access type from None to Can view for es-la.com                                          1734
#                                                                                                                                 ...
# deborah.park@es-la.com changed sharing permissions for English_8_H_H_Block_teachers_81cd5c09@es-la.com from None to Can edit       1
# ...

# %%
df['Event_Name'].value_counts()
# Out:
# View                               31192
# User Sharing Permissions Change    24906
# Edit                               22923
# Download                            7987
# Create                              3444
# Link Sharing visibility change      2758
# Link Sharing Access Type Change     2255
# Add to folder                       1395
# Move                                1078
# Rename                               830
# Delete                               690
# Upload                               440
# Trash                                182
# Print                                 33
# Restore                               25
# Remove from folder                     6
# Editor Settings Change                 5
# Name: Event_Name, dtype: int64

# %%
df['Visibility'].value_counts()
# Out:
# Shared Externally                         56571
# Private                                   26804
# Shared Internally                          9962
# Anyone with the link                       2960
# Anyone with the link within the domain     2637
# Anyone within the domain                   1077
# Public on the web                           138
# Name: Visibility, dtype: int64

# %%
df['Item_name'].value_counts()
# Out:
# Untitled document                                                   3610
# ESLA Online Learning Schedule ENGLISH                               1281
# Updated Faculty Schedule for March 16-20                             735
# Untitled presentation                                                531
# Schedule March 17 & 20                                               506
#                                                                     ...
# McCarronWeek2Summaries.docx                                            1
# Art and Social Change: Radical Women                                   1
# Mexican L.A., 1910s - 1930s: Part Three, Housing and Family Life       1
# IMG_4883.JPG                                                           1
# 782332-import-debug-1.log                                              1
# Name: Item_name, Length: 10187, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Google Docs             77548
# Google Slides            5094
# JPEG image               3812
# PNG image                2843
# Folder                   2601
# PDF                      2471
# Microsoft Word           1799
# Google Sheets            1484
# MP4 video                 806
# Google Forms              466
# Unknown                   356
# Quicktime video           286
# Plain text                270
# Microsoft Powerpoint      172
# Google Drawings            41
# MPEG audio                 40
# Google Sites               37
# Microsoft Excel            23
# Name: Item_Type, dtype: int64

# %%
df['IP_Address'].value_counts()
# Out:
# 198.44.213.18                              11665
# 52.2.46.34                                  6741
# 98.153.179.26                                516
# 104.35.229.116                               503
# 107.185.46.56                                384
#                                            ...
# 2600:1012:b041:9b86:6d99:ad61:1194:bed9        1
# 2605:e000:1302:42b3:40fb:f6de:d5ac:7a14        1
# 2600:1700:d281:1b40:c80e:7850:c6ac:b01f        1
# 107.77.227.175                                 1
# 107.77.227.116                                 1
# Name: IP_Address, Length: 1481, dtype: int64

# %%
df['Prior_Visibility'].value_counts()
# Out:
# Shared Externally                         26547
# Private                                    2437
# Anyone within the domain                    477
# Anyone with the link within the domain      208
# Shared Internally                           170
# Anyone with the link                         84
# Public on the web                             1
# Name: Prior_Visibility, dtype: int64
